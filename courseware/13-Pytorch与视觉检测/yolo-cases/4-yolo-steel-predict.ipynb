# %%
from ultralytics import YOLO
import os

# 加载训练好的模型
model2 = YOLO('./runs/detect/train31/weights/best.pt') 
#model2

# 在单张图像上测试模型
test_image_dir = './steel_data/test/images'
if os.path.exists(test_image_dir):
    for image_name in os.listdir(test_image_dir)[:5]:  # 测试前5张图片
        image_path = os.path.join(test_image_dir, image_name)
        results = model2(image_path)
        # 保存预测结果
        results[0].save(os.path.join('./runs/detect/predict', image_name))
# Out:
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1400.jpg: 640x640 (no detections), 12.6ms
# Speed: 3.1ms preprocess, 12.6ms inference, 23.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1401.jpg: 640x640 1 inclusion, 13.1ms
# Speed: 2.9ms preprocess, 13.1ms inference, 368.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1402.jpg: 640x640 4 pitted_surfaces, 12.9ms
# Speed: 2.8ms preprocess, 12.9ms inference, 26.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1403.jpg: 640x640 3 scratchess, 13.0ms
# Speed: 2.7ms preprocess, 13.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1404.jpg: 640x640 5 pitted_surfaces, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO
import os
import pandas as pd
import numpy as np
from PIL import Image

def convert_to_submission_format(results, image_name, img_shape):
    """将YOLO预测结果转换为submission格式"""
    # 获取图像ID（去掉.jpg后缀）
    image_id = int(image_name.split('.')[0])
    
    # 获取预测框、类别和置信度
    boxes = results[0].boxes
    submission_rows = []
    
    if len(boxes) > 0:
        # 获取xyxy格式的边界框（绝对坐标）
        xyxy = boxes.xyxy.cpu().numpy()
        # 获取置信度
        conf = boxes.conf.cpu().numpy()
        # 获取类别
        cls = boxes.cls.cpu().numpy()
        
        # 转换每个预测框
        for box, category_id, confidence in zip(xyxy, cls, conf):
            # 转换为整数坐标
            box = [int(x) for x in box]
            # 创建submission行
            submission_rows.append({
                'image_id': image_id,
                'bbox': str(box),  # 转换为字符串格式
                'category_id': int(category_id),
                'confidence': float(confidence)
            })
    
    return submission_rows

def main():
    # 加载训练好的模型
    model = YOLO('./runs/detect/train31/weights/best.pt')
    
    # 存储所有预测结果
    all_predictions = []
    
    # 在测试集上预测
    test_image_dir = './steel_data/test/images'
    if os.path.exists(test_image_dir):
        # 遍历所有测试图像
        for image_name in os.listdir(test_image_dir):
            if not image_name.endswith('.jpg'):
                continue
                
            # 读取图像以获取尺寸
            img_path = os.path.join(test_image_dir, image_name)
            img = Image.open(img_path)
            img_shape = img.size  # (width, height)
            
            # 进行预测
            results = model(img_path)
            
            # 保存可视化结果
            results[0].save(os.path.join('./runs/detect/predict', image_name))
            
            # 转换为submission格式并添加到列表
            submission_rows = convert_to_submission_format(results, image_name, img_shape)
            all_predictions.extend(submission_rows)
    
    # 创建DataFrame并保存为CSV
    if all_predictions:
        df = pd.DataFrame(all_predictions)
        df.to_csv('submission.csv', index=False)
        print(f"已保存预测结果到 submission.csv，共 {len(df)} 个预测框")
    else:
        print("没有找到任何预测结果")

if __name__ == '__main__':
    main()
# Out:
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1400.jpg: 640x640 (no detections), 15.8ms
# Speed: 2.8ms preprocess, 15.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1401.jpg: 640x640 1 inclusion, 14.9ms
# Speed: 2.3ms preprocess, 14.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1402.jpg: 640x640 4 pitted_surfaces, 14.8ms
# Speed: 2.3ms preprocess, 14.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1403.jpg: 640x640 3 scratchess, 14.7ms
# Speed: 2.6ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1404.jpg: 640x640 5 pitted_surfaces, 15.4ms
# Speed: 2.3ms preprocess, 15.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1405.jpg: 640x640 6 pitted_surfaces, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1406.jpg: 640x640 4 pitted_surfaces, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1407.jpg: 640x640 3 pitted_surfaces, 19.1ms
# Speed: 2.3ms preprocess, 19.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1408.jpg: 640x640 5 pitted_surfaces, 14.8ms
# Speed: 2.3ms preprocess, 14.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1409.jpg: 640x640 6 pitted_surfaces, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1410.jpg: 640x640 (no detections), 15.0ms
# Speed: 3.5ms preprocess, 15.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1411.jpg: 640x640 2 inclusions, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1412.jpg: 640x640 (no detections), 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1413.jpg: 640x640 4 pitted_surfaces, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1414.jpg: 640x640 1 inclusion, 2 scratchess, 14.9ms
# Speed: 2.3ms preprocess, 14.9ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1415.jpg: 640x640 8 patchess, 18.0ms
# Speed: 2.3ms preprocess, 18.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1416.jpg: 640x640 (no detections), 14.8ms
# Speed: 2.3ms preprocess, 14.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1417.jpg: 640x640 1 scratches, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1418.jpg: 640x640 (no detections), 15.2ms
# Speed: 2.3ms preprocess, 15.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1419.jpg: 640x640 (no detections), 14.5ms
# Speed: 2.4ms preprocess, 14.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1420.jpg: 640x640 1 rolled-in_scale, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1421.jpg: 640x640 2 patchess, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1422.jpg: 640x640 4 pitted_surfaces, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1423.jpg: 640x640 (no detections), 17.5ms
# Speed: 2.3ms preprocess, 17.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1424.jpg: 640x640 5 patchess, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1425.jpg: 640x640 2 patchess, 14.6ms
# Speed: 2.8ms preprocess, 14.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1426.jpg: 640x640 4 scratchess, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1427.jpg: 640x640 (no detections), 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1428.jpg: 640x640 (no detections), 14.8ms
# Speed: 3.1ms preprocess, 14.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1429.jpg: 640x640 2 inclusions, 16.2ms
# Speed: 2.3ms preprocess, 16.2ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1430.jpg: 640x640 2 patchess, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1431.jpg: 640x640 1 scratches, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1432.jpg: 640x640 3 patchess, 17.7ms
# Speed: 2.3ms preprocess, 17.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1433.jpg: 640x640 (no detections), 15.5ms
# Speed: 2.3ms preprocess, 15.5ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1434.jpg: 640x640 (no detections), 14.8ms
# Speed: 2.7ms preprocess, 14.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1435.jpg: 640x640 (no detections), 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1436.jpg: 640x640 3 inclusions, 16.1ms
# Speed: 2.3ms preprocess, 16.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1437.jpg: 640x640 5 pitted_surfaces, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1438.jpg: 640x640 1 patches, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1439.jpg: 640x640 (no detections), 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1440.jpg: 640x640 (no detections), 14.9ms
# Speed: 2.3ms preprocess, 14.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1441.jpg: 640x640 (no detections), 14.8ms
# Speed: 2.3ms preprocess, 14.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1442.jpg: 640x640 1 inclusion, 14.9ms
# Speed: 2.3ms preprocess, 14.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1443.jpg: 640x640 (no detections), 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1444.jpg: 640x640 4 pitted_surfaces, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1445.jpg: 640x640 (no detections), 14.8ms
# Speed: 2.3ms preprocess, 14.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1446.jpg: 640x640 (no detections), 16.8ms
# Speed: 2.3ms preprocess, 16.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1447.jpg: 640x640 (no detections), 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1448.jpg: 640x640 4 patchess, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1449.jpg: 640x640 3 patchess, 16.0ms
# Speed: 2.3ms preprocess, 16.0ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1450.jpg: 640x640 3 scratchess, 14.8ms
# Speed: 2.3ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1451.jpg: 640x640 (no detections), 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1452.jpg: 640x640 1 patches, 14.8ms
# Speed: 2.3ms preprocess, 14.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1453.jpg: 640x640 2 inclusions, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1454.jpg: 640x640 1 inclusion, 1 pitted_surface, 14.8ms
# Speed: 3.4ms preprocess, 14.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1455.jpg: 640x640 1 inclusion, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1456.jpg: 640x640 7 inclusions, 15.5ms
# Speed: 3.8ms preprocess, 15.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1457.jpg: 640x640 5 patchess, 14.6ms
# Speed: 2.5ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1458.jpg: 640x640 4 pitted_surfaces, 14.5ms
# Speed: 4.2ms preprocess, 14.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1459.jpg: 640x640 3 inclusions, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1460.jpg: 640x640 (no detections), 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1461.jpg: 640x640 2 scratchess, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1462.jpg: 640x640 2 scratchess, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1463.jpg: 640x640 2 pitted_surfaces, 17.1ms
# Speed: 2.3ms preprocess, 17.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1464.jpg: 640x640 3 patchess, 15.1ms
# Speed: 2.3ms preprocess, 15.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1465.jpg: 640x640 (no detections), 14.9ms
# Speed: 2.3ms preprocess, 14.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1466.jpg: 640x640 1 inclusion, 13.7ms
# Speed: 3.2ms preprocess, 13.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1467.jpg: 640x640 5 patchess, 13.3ms
# Speed: 2.3ms preprocess, 13.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1468.jpg: 640x640 3 pitted_surfaces, 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1469.jpg: 640x640 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1470.jpg: 640x640 1 rolled-in_scale, 12.7ms
# Speed: 2.2ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1471.jpg: 640x640 (no detections), 12.6ms
# Speed: 2.0ms preprocess, 12.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1472.jpg: 640x640 2 pitted_surfaces, 13.0ms
# Speed: 1.9ms preprocess, 13.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1473.jpg: 640x640 (no detections), 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1474.jpg: 640x640 (no detections), 12.1ms
# Speed: 2.8ms preprocess, 12.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1475.jpg: 640x640 2 scratchess, 11.9ms
# Speed: 1.9ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1476.jpg: 640x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1477.jpg: 640x640 4 inclusions, 12.3ms
# Speed: 1.9ms preprocess, 12.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1478.jpg: 640x640 2 inclusions, 11.9ms
# Speed: 1.9ms preprocess, 11.9ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1479.jpg: 640x640 (no detections), 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1480.jpg: 640x640 3 inclusions, 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1481.jpg: 640x640 (no detections), 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1482.jpg: 640x640 (no detections), 12.5ms
# Speed: 1.9ms preprocess, 12.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1483.jpg: 640x640 (no detections), 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1484.jpg: 640x640 1 inclusion, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1485.jpg: 640x640 2 patchess, 11.8ms
# Speed: 1.7ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1486.jpg: 640x640 1 scratches, 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1487.jpg: 640x640 3 scratchess, 11.7ms
# Speed: 1.9ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1488.jpg: 640x640 4 scratchess, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1489.jpg: 640x640 2 inclusions, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1490.jpg: 640x640 (no detections), 11.7ms
# Speed: 1.9ms preprocess, 11.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1491.jpg: 640x640 (no detections), 13.6ms
# Speed: 2.6ms preprocess, 13.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1492.jpg: 640x640 2 inclusions, 11.2ms
# Speed: 1.9ms preprocess, 11.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1493.jpg: 640x640 (no detections), 11.8ms
# Speed: 1.8ms preprocess, 11.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1494.jpg: 640x640 8 patchess, 11.5ms
# Speed: 1.9ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1495.jpg: 640x640 1 rolled-in_scale, 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1496.jpg: 640x640 4 pitted_surfaces, 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1497.jpg: 640x640 1 pitted_surface, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1498.jpg: 640x640 3 patchess, 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1499.jpg: 640x640 (no detections), 12.3ms
# Speed: 1.9ms preprocess, 12.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1500.jpg: 640x640 1 patches, 11.7ms
# Speed: 1.9ms preprocess, 11.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1501.jpg: 640x640 2 inclusions, 11.6ms
# Speed: 1.9ms preprocess, 11.6ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1502.jpg: 640x640 1 rolled-in_scale, 11.4ms
# Speed: 2.5ms preprocess, 11.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1503.jpg: 640x640 (no detections), 11.6ms
# Speed: 1.9ms preprocess, 11.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1504.jpg: 640x640 (no detections), 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1505.jpg: 640x640 2 patchess, 12.7ms
# Speed: 2.1ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1506.jpg: 640x640 2 rolled-in_scales, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1507.jpg: 640x640 3 inclusions, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1508.jpg: 640x640 (no detections), 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1509.jpg: 640x640 1 rolled-in_scale, 14.5ms
# Speed: 3.1ms preprocess, 14.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1510.jpg: 640x640 3 pitted_surfaces, 14.9ms
# Speed: 2.2ms preprocess, 14.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1511.jpg: 640x640 1 inclusion, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1512.jpg: 640x640 3 patchess, 14.6ms
# Speed: 2.2ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1513.jpg: 640x640 (no detections), 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1514.jpg: 640x640 1 scratches, 15.0ms
# Speed: 2.3ms preprocess, 15.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1515.jpg: 640x640 4 pitted_surfaces, 14.5ms
# Speed: 2.2ms preprocess, 14.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1516.jpg: 640x640 (no detections), 15.1ms
# Speed: 3.5ms preprocess, 15.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1517.jpg: 640x640 2 scratchess, 15.4ms
# Speed: 2.4ms preprocess, 15.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1518.jpg: 640x640 (no detections), 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1519.jpg: 640x640 3 pitted_surfaces, 14.4ms
# Speed: 2.3ms preprocess, 14.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1520.jpg: 640x640 (no detections), 14.8ms
# Speed: 2.5ms preprocess, 14.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1521.jpg: 640x640 1 rolled-in_scale, 14.5ms
# Speed: 2.4ms preprocess, 14.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1522.jpg: 640x640 (no detections), 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1523.jpg: 640x640 2 inclusions, 14.6ms
# Speed: 2.4ms preprocess, 14.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1524.jpg: 640x640 3 pitted_surfaces, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1525.jpg: 640x640 4 scratchess, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1526.jpg: 640x640 4 inclusions, 17.1ms
# Speed: 2.3ms preprocess, 17.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1527.jpg: 640x640 4 inclusions, 15.4ms
# Speed: 2.9ms preprocess, 15.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1528.jpg: 640x640 (no detections), 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1529.jpg: 640x640 4 patchess, 14.5ms
# Speed: 2.2ms preprocess, 14.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1530.jpg: 640x640 (no detections), 14.5ms
# Speed: 2.2ms preprocess, 14.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1531.jpg: 640x640 3 patchess, 14.3ms
# Speed: 2.2ms preprocess, 14.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1532.jpg: 640x640 (no detections), 14.5ms
# Speed: 2.2ms preprocess, 14.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1533.jpg: 640x640 1 inclusion, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1534.jpg: 640x640 2 inclusions, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1535.jpg: 640x640 1 pitted_surface, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1536.jpg: 640x640 (no detections), 14.5ms
# Speed: 2.6ms preprocess, 14.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1537.jpg: 640x640 4 inclusions, 16.0ms
# Speed: 2.3ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1538.jpg: 640x640 3 pitted_surfaces, 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1539.jpg: 640x640 (no detections), 14.6ms
# Speed: 2.2ms preprocess, 14.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1540.jpg: 640x640 1 inclusion, 14.8ms
# Speed: 2.3ms preprocess, 14.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1541.jpg: 640x640 1 inclusion, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1542.jpg: 640x640 2 scratchess, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1543.jpg: 640x640 (no detections), 14.5ms
# Speed: 2.2ms preprocess, 14.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1544.jpg: 640x640 (no detections), 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1545.jpg: 640x640 3 inclusions, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1546.jpg: 640x640 5 pitted_surfaces, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1547.jpg: 640x640 4 pitted_surfaces, 14.6ms
# Speed: 2.2ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1548.jpg: 640x640 3 pitted_surfaces, 15.1ms
# Speed: 3.5ms preprocess, 15.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1549.jpg: 640x640 3 pitted_surfaces, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1550.jpg: 640x640 1 rolled-in_scale, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1551.jpg: 640x640 (no detections), 14.9ms
# Speed: 2.3ms preprocess, 14.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1552.jpg: 640x640 (no detections), 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1553.jpg: 640x640 3 patchess, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1554.jpg: 640x640 4 patchess, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1555.jpg: 640x640 4 patchess, 13.3ms
# Speed: 3.3ms preprocess, 13.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1556.jpg: 640x640 4 patchess, 11.5ms
# Speed: 1.9ms preprocess, 11.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1557.jpg: 640x640 (no detections), 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1558.jpg: 640x640 3 scratchess, 13.4ms
# Speed: 2.6ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1559.jpg: 640x640 3 inclusions, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1560.jpg: 640x640 (no detections), 13.3ms
# Speed: 4.1ms preprocess, 13.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1561.jpg: 640x640 1 rolled-in_scale, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1562.jpg: 640x640 2 pitted_surfaces, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1563.jpg: 640x640 3 pitted_surfaces, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1564.jpg: 640x640 3 inclusions, 12.8ms
# Speed: 2.0ms preprocess, 12.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1565.jpg: 640x640 5 patchess, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1566.jpg: 640x640 2 scratchess, 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1567.jpg: 640x640 1 scratches, 12.5ms
# Speed: 1.9ms preprocess, 12.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1568.jpg: 640x640 2 patchess, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1569.jpg: 640x640 (no detections), 20.3ms
# Speed: 5.0ms preprocess, 20.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1570.jpg: 640x640 4 pitted_surfaces, 20.8ms
# Speed: 4.7ms preprocess, 20.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1571.jpg: 640x640 (no detections), 21.0ms
# Speed: 4.6ms preprocess, 21.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1572.jpg: 640x640 (no detections), 20.8ms
# Speed: 4.1ms preprocess, 20.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1573.jpg: 640x640 (no detections), 20.6ms
# Speed: 4.8ms preprocess, 20.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1574.jpg: 640x640 (no detections), 19.5ms
# Speed: 5.0ms preprocess, 19.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1575.jpg: 640x640 3 pitted_surfaces, 20.3ms
# Speed: 4.5ms preprocess, 20.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1576.jpg: 640x640 (no detections), 14.3ms
# Speed: 2.2ms preprocess, 14.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1577.jpg: 640x640 4 patchess, 14.4ms
# Speed: 2.3ms preprocess, 14.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1578.jpg: 640x640 3 inclusions, 14.3ms
# Speed: 2.2ms preprocess, 14.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1579.jpg: 640x640 (no detections), 14.3ms
# Speed: 2.2ms preprocess, 14.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1580.jpg: 640x640 (no detections), 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1581.jpg: 640x640 3 inclusions, 3 scratchess, 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1582.jpg: 640x640 4 pitted_surfaces, 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1583.jpg: 640x640 3 patchess, 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1584.jpg: 640x640 2 inclusions, 14.0ms
# Speed: 2.2ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1585.jpg: 640x640 (no detections), 16.6ms
# Speed: 2.3ms preprocess, 16.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1586.jpg: 640x640 (no detections), 13.9ms
# Speed: 2.2ms preprocess, 13.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1587.jpg: 640x640 2 inclusions, 13.9ms
# Speed: 2.1ms preprocess, 13.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1588.jpg: 640x640 3 inclusions, 14.0ms
# Speed: 2.2ms preprocess, 14.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1589.jpg: 640x640 3 pitted_surfaces, 14.0ms
# Speed: 2.2ms preprocess, 14.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1590.jpg: 640x640 (no detections), 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1591.jpg: 640x640 (no detections), 13.9ms
# Speed: 2.2ms preprocess, 13.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1592.jpg: 640x640 3 pitted_surfaces, 14.1ms
# Speed: 2.1ms preprocess, 14.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1593.jpg: 640x640 (no detections), 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1594.jpg: 640x640 (no detections), 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1595.jpg: 640x640 (no detections), 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1596.jpg: 640x640 2 scratchess, 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1597.jpg: 640x640 1 rolled-in_scale, 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1598.jpg: 640x640 (no detections), 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1599.jpg: 640x640 1 patches, 14.3ms
# Speed: 2.2ms preprocess, 14.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1600.jpg: 640x640 (no detections), 11.7ms
# Speed: 1.9ms preprocess, 11.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1601.jpg: 640x640 4 patchess, 11.5ms
# Speed: 1.8ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1602.jpg: 640x640 2 inclusions, 12.8ms
# Speed: 2.9ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1603.jpg: 640x640 4 pitted_surfaces, 1 patches, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1604.jpg: 640x640 (no detections), 15.1ms
# Speed: 3.5ms preprocess, 15.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1605.jpg: 640x640 3 inclusions, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1606.jpg: 640x640 1 inclusion, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1607.jpg: 640x640 2 inclusions, 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1608.jpg: 640x640 3 inclusions, 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1609.jpg: 640x640 4 pitted_surfaces, 13.8ms
# Speed: 2.2ms preprocess, 13.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1610.jpg: 640x640 (no detections), 13.7ms
# Speed: 2.4ms preprocess, 13.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1611.jpg: 640x640 (no detections), 14.0ms
# Speed: 2.5ms preprocess, 14.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1612.jpg: 640x640 (no detections), 14.3ms
# Speed: 2.8ms preprocess, 14.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1613.jpg: 640x640 (no detections), 21.4ms
# Speed: 4.0ms preprocess, 21.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1614.jpg: 640x640 (no detections), 19.8ms
# Speed: 4.8ms preprocess, 19.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1615.jpg: 640x640 2 inclusions, 16.1ms
# Speed: 4.9ms preprocess, 16.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1616.jpg: 640x640 (no detections), 12.8ms
# Speed: 1.9ms preprocess, 12.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1617.jpg: 640x640 3 patchess, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1618.jpg: 640x640 (no detections), 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1619.jpg: 640x640 (no detections), 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1620.jpg: 640x640 2 scratchess, 14.2ms
# Speed: 1.9ms preprocess, 14.2ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1621.jpg: 640x640 (no detections), 12.5ms
# Speed: 2.4ms preprocess, 12.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1622.jpg: 640x640 (no detections), 12.2ms
# Speed: 1.9ms preprocess, 12.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# ...
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1726.jpg: 640x640 3 patchess, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1727.jpg: 640x640 3 patchess, 12.3ms
# Speed: 1.9ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1728.jpg: 640x640 1 scratches, 12.8ms
# Speed: 2.9ms preprocess, 12.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1729.jpg: 640x640 (no detections), 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1730.jpg: 640x640 4 pitted_surfaces, 12.7ms
# Speed: 1.9ms preprocess, 12.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1731.jpg: 640x640 (no detections), 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1732.jpg: 640x640 4 patchess, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1733.jpg: 640x640 1 scratches, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1734.jpg: 640x640 1 rolled-in_scale, 13.4ms
# Speed: 2.0ms preprocess, 13.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1735.jpg: 640x640 3 pitted_surfaces, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1736.jpg: 640x640 (no detections), 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1737.jpg: 640x640 (no detections), 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1738.jpg: 640x640 1 rolled-in_scale, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1739.jpg: 640x640 3 pitted_surfaces, 13.3ms
# Speed: 1.9ms preprocess, 13.3ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1740.jpg: 640x640 4 pitted_surfaces, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1741.jpg: 640x640 4 patchess, 13.8ms
# Speed: 3.4ms preprocess, 13.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1742.jpg: 640x640 (no detections), 12.2ms
# Speed: 1.9ms preprocess, 12.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1743.jpg: 640x640 1 inclusion, 1 scratches, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1744.jpg: 640x640 1 patches, 12.6ms
# Speed: 1.9ms preprocess, 12.6ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1745.jpg: 640x640 2 patchess, 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1746.jpg: 640x640 3 pitted_surfaces, 1 patches, 11.6ms
# Speed: 1.9ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1747.jpg: 640x640 4 patchess, 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1748.jpg: 640x640 (no detections), 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1749.jpg: 640x640 2 scratchess, 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1750.jpg: 640x640 1 pitted_surface, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1751.jpg: 640x640 3 pitted_surfaces, 12.2ms
# Speed: 1.9ms preprocess, 12.2ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1752.jpg: 640x640 3 patchess, 11.9ms
# Speed: 1.9ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1753.jpg: 640x640 (no detections), 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1754.jpg: 640x640 1 scratches, 12.2ms
# Speed: 1.9ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1755.jpg: 640x640 (no detections), 12.2ms
# Speed: 1.9ms preprocess, 12.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1756.jpg: 640x640 1 inclusion, 2 scratchess, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 8.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1757.jpg: 640x640 (no detections), 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1758.jpg: 640x640 2 inclusions, 11.3ms
# Speed: 1.8ms preprocess, 11.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1759.jpg: 640x640 (no detections), 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1760.jpg: 640x640 3 patchess, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1761.jpg: 640x640 (no detections), 14.3ms
# Speed: 1.9ms preprocess, 14.3ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1762.jpg: 640x640 3 pitted_surfaces, 12.0ms
# Speed: 2.1ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1763.jpg: 640x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1764.jpg: 640x640 (no detections), 11.9ms
# Speed: 1.9ms preprocess, 11.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1765.jpg: 640x640 2 patchess, 12.3ms
# Speed: 1.9ms preprocess, 12.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1766.jpg: 640x640 (no detections), 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1767.jpg: 640x640 (no detections), 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1768.jpg: 640x640 3 patchess, 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1769.jpg: 640x640 3 patchess, 12.2ms
# Speed: 2.6ms preprocess, 12.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1770.jpg: 640x640 2 scratchess, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1771.jpg: 640x640 (no detections), 12.5ms
# Speed: 1.9ms preprocess, 12.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1772.jpg: 640x640 2 inclusions, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1773.jpg: 640x640 6 pitted_surfaces, 13.0ms
# Speed: 1.9ms preprocess, 13.0ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1774.jpg: 640x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1775.jpg: 640x640 (no detections), 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1776.jpg: 640x640 (no detections), 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1777.jpg: 640x640 4 pitted_surfaces, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1778.jpg: 640x640 5 patchess, 15.6ms
# Speed: 1.9ms preprocess, 15.6ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1779.jpg: 640x640 3 patchess, 13.1ms
# Speed: 2.5ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1780.jpg: 640x640 6 patchess, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1781.jpg: 640x640 (no detections), 12.3ms
# Speed: 1.9ms preprocess, 12.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1782.jpg: 640x640 6 pitted_surfaces, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1783.jpg: 640x640 (no detections), 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1784.jpg: 640x640 3 inclusions, 12.2ms
# Speed: 2.3ms preprocess, 12.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1785.jpg: 640x640 1 patches, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1786.jpg: 640x640 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1787.jpg: 640x640 1 rolled-in_scale, 12.6ms
# Speed: 2.1ms preprocess, 12.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1788.jpg: 640x640 (no detections), 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1789.jpg: 640x640 2 scratchess, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1790.jpg: 640x640 2 patchess, 11.9ms
# Speed: 1.9ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1791.jpg: 640x640 (no detections), 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1792.jpg: 640x640 4 pitted_surfaces, 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1793.jpg: 640x640 (no detections), 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1794.jpg: 640x640 2 pitted_surfaces, 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1795.jpg: 640x640 3 inclusions, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1796.jpg: 640x640 (no detections), 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1797.jpg: 640x640 (no detections), 12.3ms
# Speed: 2.6ms preprocess, 12.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1798.jpg: 640x640 3 pitted_surfaces, 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /root/autodl-tmp/vl_model_cases/yolo-cases/steel_data/test/images/1799.jpg: 640x640 (no detections), 12.3ms
# Speed: 1.9ms preprocess, 12.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 已保存预测结果到 submission.csv，共 743 个预测框
