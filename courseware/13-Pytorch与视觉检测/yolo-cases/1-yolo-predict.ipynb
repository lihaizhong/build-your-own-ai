# %%
## 使用yolo12进行预测

# %%
from ultralytics import YOLO

model = YOLO('./yolov12n.pt')
# 使用model进行目标检测
results = model("/root/autodl-tmp/datasets/coco/images/val2017/000000000139.jpg")
results[0].show()
# Out:
# image 1/1 /root/autodl-tmp/datasets/coco/images/val2017/000000000139.jpg: 448x640 2 persons, 3 chairs, 2 potted plants, 1 dining table, 2 tvs, 1 refrigerator, 1 clock, 1 vase, 65.8ms
# Speed: 2.1ms preprocess, 65.8ms inference, 487.2ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=640x426>

# %%
# 在验证集上评估
metrics = model.val(data='./coco.yaml', save_json=True)
print(metrics.box.map)  # 打印mAP指标
# Out:
# Ultralytics 8.3.63 🚀 Python-3.10.8 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
# val: Scanning /root/autodl-tmp/datasets/coco/labels/val2017.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|██████████| 30/30 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.43it/s]
#                    all         30        201      0.734      0.537      0.688      0.503
#                 person         22         57      0.962      0.899      0.955       0.78
#                    car          3         11      0.815      0.802      0.884       0.63
#                    bus          1          1      0.626          1      0.995      0.995
#                  truck          2          2      0.868          1      0.995      0.995
#                   boat          1          1      0.643          1      0.995      0.326
#              stop sign          1          1          1          0      0.995      0.895
#          parking meter          1          1        0.6          1      0.995      0.895
#                  bench          1          1      0.397          1      0.995      0.895
#                   bird          1          1          1          0      0.249      0.199
#                    cat          1          2      0.837          1      0.995       0.55
#                  horse          2          3      0.861          1      0.995      0.765
#                    cow          1          1      0.692          1      0.995      0.995
#                giraffe          1          2      0.793          1      0.995      0.951
#               backpack          2          2          1          0     0.0444     0.0355
#               umbrella          1          5          1          0      0.306      0.096
#                    tie          2          2      0.365      0.365      0.263      0.228
#                   skis          2          4      0.815       0.25       0.62      0.245
#            sports ball          4          4      0.536      0.305      0.426      0.324
#           baseball bat          3          7      0.791      0.545      0.543      0.407
#         baseball glove          3          7      0.274      0.143       0.18     0.0489
#             skateboard          2          3      0.875          1      0.995      0.687
#              surfboard          1          4          1          0      0.203     0.0443
#          tennis racket          1          1      0.548          1      0.995      0.796
#                 bottle          2          5      0.446        0.2      0.402      0.145
#             wine glass          1          1          1          0          0          0
#                    cup          3          3      0.586      0.506      0.558      0.446
#                  spoon          1          1          1          0          0          0
#                   bowl          2         12      0.784      0.607       0.81      0.652
#                 banana          2         26      0.266     0.0385      0.259       0.12
#                  apple          1          3          1          0      0.416      0.367
#               sandwich          1          2      0.713        0.5      0.505       0.15
#               broccoli          1          5      0.293        0.2      0.478      0.154
#                 carrot          1          1          0          0      0.332      0.199
#                  pizza          1          1      0.778          1      0.995      0.398
#                   cake          1          2          1          0      0.224      0.141
#                  chair          3          7          1      0.281      0.721      0.403
#                  couch          1          1      0.682          1      0.995      0.995
#           potted plant          1          1          1          0      0.995      0.597
#           dining table          1          1      0.785          1      0.995      0.697
#                     tv          1          1      0.688          1      0.995      0.895
#                 laptop          1          1      0.695          1      0.995      0.995
#                   oven          1          1          1          0      0.995      0.597
#           refrigerator          1          1      0.647          1      0.995      0.796
#                  clock          1          2      0.637          1      0.995      0.599
# Speed: 1.6ms preprocess, 25.6ms inference, 0.0ms loss, 1.2ms postprocess per image
# Saving runs/detect/val4/predictions.json...
# Results saved to runs/detect/val4
# 0.5029502302232565
